# %%
print("Hello World!")
# Out:
# Hello World!

# %%
name = input("Nhập tên của bạn: ")
print("Xin chào", name)
# Out:
# Xin chào quynh

# %%
a = int(input())
b = int(input())

print(a + b)
print(a - b)
print(a * b)
print(a // b)
print(a % b)
print(f"{a / b:.2f}")
# Out:
# 11
# -1
# 30
# 0
# 5
# 0.83

# %%
a1, b1, c1, a2, b2, a3 = map(float, input().split())
tb = ((a1 + b1 + c1) + (a2 + b2) * 2 + a3 * 3) / 10
print(f"{tb:.1f}")
# Out:
# 5.3

# %%
a, b = map(int, input().split())
print(a ** b)
# Out:
# 25

# %%
ch = input()              # nhập 1 kí tự thường
print(ord(ch))            # in mã Unicode của kí tự vừa nhập
ch_hoa = ch.upper()       # chuyển sang chữ hoa
print(ch_hoa)             # in chữ hoa
# Out:
# 113
# Q

# %%
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5

print(A)
print(B)
# Out:
# 512
# 512

# %%
c = float(input())
f = 9/5 * c + 32
print(f"{f:.2f}")
# Out:
# 80.60

# %%
#bai9
x = float(input("Nhập giá đồng hồ (USD): "))
shipping_fee = 10
subtotal = x + shipping_fee
import_tax = 0.3 * subtotal
vat_tax = 0.1 * subtotal
total = subtotal + import_tax + vat_tax
print(f"Tổng số tiền phải trả: {total:.2f} USD")
# Out:
# Tổng số tiền phải trả: 154.00 USD

# %%
#bài 10
names = input("Nhập tên 3 người (cách nhau bằng dấu cách): ").split()
names.reverse()
print(f"Hi {names[0]}, {names[1]} and {names[2]}.")
# Out:
# Hi Helen, Alice and Bob.

# %%
# Nhập giờ và phút cách nhau bởi dấu cách
h, m = map(int, input().split())

# Tính tổng số giây
seconds = h*3600 + m*60

# In kết quả
print(seconds)
# Out:
# 9000

# %%
# Nhập độ dài cạnh khối Rubik
n = int(input("Nhập độ dài cạnh n: "))

# Tính số miếng dán
stickers = 6 * n * n

# In kết quả
print(stickers)
# Out:
# 6

# %%
# Nhập hai số nguyên dương
a, b = map(int, input().split())

# Tính chữ số hàng đơn vị của tích
print((a * b) % 10)
# Out:
# 6

# %%
# Nhập hai số a và b
a, b = map(int, input().split())

# Hoán đổi giá trị
a, b = b, a

# In kết quả
print(a, b)
# Out:
# 10 5

# %%
# Nhập số nguyên dương n
n = int(input("Nhập n: "))

# Tính số sao thứ n
star_number = 3 * n * (n - 1) + 1

# In kết quả
print(star_number)
# Out:
# 7

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
print("*\n***\n*****")
# Out:
# *
# ***
# *****

# %%
print("### # #   ### ###")
print(" #  #  #   #   #")
print(" #  #   #  #   #")
print(" #  #  #   #   #")
print(" #  # #    #   #")
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
for _ in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
