# %%
def reverse(path: str) -> int:
    with open(path, "r" ) as f:
        n = f.read().strip()
    return int(n[::-1])

# %%
#w11a4
def areAnagrams(path1: str, path2: str) -> bool:
    with open(path1, 'r') as f1:
        str1 = f1.read().lower()
    with open(path2, 'r') as f2:
        str2 = f2.read().lower()
    str1 = ''.join(c for c in s1 if c.isalpha())
    str2 = ''.join(c for c in s2 if c.isalpha())

    return sorted(str1) == sorted(str2)

path1 = input().strip()
path2 = input().strip()
result = areAnagrams(path1, path2)
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 14
#      12 path1 = input().strip()
#      13 path2 = input().strip()
# ---> 14 result = areAnagrams(path1, path2)
#      15 print(result)
#
# Cell In[7], line 3, in areAnagrams(path1, path2)
#       2 def areAnagrams(path1: str, path2: str) -> bool:
# ----> 3     with open(path1, 'r') as f1:
#       4         str1 = f1.read().lower()
#       5     with open(path2, 'r') as f2:
#
# File ~/Documents/quỳnh code/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# ...

# %%
import math 
def day(n):
    a=math.prod(n)
    e=[]
    for i in range(len(n)):
        d=a//n[i]
        e.append(d)
    return e
print(day([4, 6, 2, 5, 2]))
# Out:
# [120, 80, 240, 96, 240]
