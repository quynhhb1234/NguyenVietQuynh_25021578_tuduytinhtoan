# %%
#bài 1
a=int(input())
b=int(input())
print(f"diện tích:{a*b}")
print(f"chu vi:{(a+b)*2}")
# Out:
# diện tích:8
# chu vi:12

# %%
#bài 2
n=int(input())
print(f"diện tích:{3.14*n*n}")
print(f"chu vi:{2*3.14*n}")
# Out:
# diện tích:28.259999999999998
# chu vi:18.84

# %%
#bài 3
import math
a=float(input())
b=float(input())
c=float(input())
if a+b <= c or a+c <= b or b+c <= a:
   print("không là ba cạnh của tam giác")
else:
   if a==b==c:
      print("tam giác đều")
   elif a==b or b==c or a==c:
      print("tam giác cân")
   elif a*a+b*b==c*c or a*a+c*c==b*b or b*b+c*c==a*a:
      print("tam giác vuông")
   else :
      print("tam giác thường")
P=a+b+c
p=P/2
S=math.sqrt(p*(p-a)*(p-b)*(p-c))
print(f"chu vi:{P}")
print(f"diện tích:{S}")
# Out:
# tam giác vuông
# chu vi:12.0
# diện tích:6.0

# %%
#bài 4
a=float(input())
b=float(input())
print("giải hệ phương trình :",a,"* x +",b,"=0")
if a==0:
    if b==0:
        print("phương trình vô số nghiệm")
    else:
        print("phương trình vô nghiệm")
else :
    x=-b/a
    print(f"phương trình có nghiệm x={x}")
# Out:
# giải hệ phương trình : 4.0 *x + 5.0 =0
# phương trình có nghiệm x=-1.25

# %%
#bài 5
import math
a, b, c = map(float, input().split())
print("giải phương trình :",a,"*x^2 +",b,"*x +",c,"=0")
d=b**2-4*a*c
if d==0:
    x=-b/(2*a)
    print(f"phương trình có nghiệm kép x1=x2={x}")
elif d>0:
    x1=(-b+math.sqrt(d))/(2*a)
    x2=(-b-math.sqrt(d))/(2*a)
    print(f"phương trình có hai nghiệm phân biệt x1={x1},x2={x2}")
else :
    print("phương trình vô nghiệm")
# Out:
# giải phương trình : 4.0 *x^2 + 5.0 *x + 6.0 =0
# phương trình vô nghiệm

# %%
#bài 6
